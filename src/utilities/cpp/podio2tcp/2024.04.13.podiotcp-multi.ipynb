# %% [markdown]
# # Run Multiple instances of EICrecon using podio over TCP
# (n.b. This is based on the fabric iperf3 example.)
#
# This will setup a node at CERN and several other nodes at:
#
# New York
# Washington D.C.
# Atlanta
# Dallas
# Los Angeles
# Seattle
# Salt Lake City
# Kansas City
#
# This will demonstrate transferring podio events and processing them using the EICrecon software from ePIC. Each site will run 4 independent eicrecon processes for a total of 32 processes. All will be pulling events from the same CERN server. The processing rate of a single process is ~1Hz so <32Hz can be achieved with this.

# %% [markdown]
# ## Import the FABlib Library

# %%
from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager

fablib = fablib_manager()

fablib.show_config();
# Out:
# <style type="text/css">
# #T_b6ae0 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_b6ae0 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_b6ae0 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_b6ae0_row0_col0, #T_b6ae0_row0_col1, #T_b6ae0_row1_col0, #T_b6ae0_row1_col1, #T_b6ae0_row2_col0, #T_b6ae0_row2_col1, #T_b6ae0_row3_col0, #T_b6ae0_row3_col1, #T_b6ae0_row4_col0, #T_b6ae0_row4_col1, #T_b6ae0_row5_col0, #T_b6ae0_row5_col1, #T_b6ae0_row6_col0, #T_b6ae0_row6_col1, #T_b6ae0_row7_col0, #T_b6ae0_row7_col1, #T_b6ae0_row8_col0, #T_b6ae0_row8_col1, #T_b6ae0_row9_col0, #T_b6ae0_row9_col1, #T_b6ae0_row10_col0, #T_b6ae0_row10_col1, #T_b6ae0_row11_col0, #T_b6ae0_row11_col1, #T_b6ae0_row12_col0, #T_b6ae0_row12_col1, #T_b6ae0_row13_col0, #T_b6ae0_row13_col1, #T_b6ae0_row14_col0, #T_b6ae0_row14_col1, #T_b6ae0_row15_col0, #T_b6ae0_row15_col1, #T_b6ae0_row16_col0, #T_b6ae0_row16_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_b6ae0">
#   <caption>FABlib Config</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b6ae0_row0_col0" class="data row0 col0" >Orchestrator</td>
#       <td id="T_b6ae0_row0_col1" class="data row0 col1" >orchestrator.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_b6ae0_row1_col0" class="data row1 col0" >Credential Manager</td>
#       <td id="T_b6ae0_row1_col1" class="data row1 col1" >cm.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_b6ae0_row2_col0" class="data row2 col0" >Core API</td>
#       <td id="T_b6ae0_row2_col1" class="data row2 col1" >uis.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_b6ae0_row3_col0" class="data row3 col0" >Token File</td>
#       <td id="T_b6ae0_row3_col1" class="data row3 col1" >/home/fabric/.tokens.json</td>
#     </tr>
#     <tr>
#       <td id="T_b6ae0_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_b6ae0_row4_col1" class="data row4 col1" >a7818636-1fa1-4e77-bb03-d171598b0862</td>
#     </tr>
#     <tr>
#       <td id="T_b6ae0_row5_col0" class="data row5 col0" >Bastion Host</td>
#       <td id="T_b6ae0_row5_col1" class="data row5 col1" >bastion.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_b6ae0_row6_col0" class="data row6 col0" >Bastion Username</td>
#       <td id="T_b6ae0_row6_col1" class="data row6 col1" >davidl_0004580836</td>
#     </tr>
#     <tr>
#       <td id="T_b6ae0_row7_col0" class="data row7 col0" >Bastion Private Key File</td>
#       <td id="T_b6ae0_row7_col1" class="data row7 col1" >/home/fabric/work/fabric_config/fabric-bastion-key</td>
#     </tr>
#     <tr>
#       <td id="T_b6ae0_row8_col0" class="data row8 col0" >Slice Public Key File</td>
#       <td id="T_b6ae0_row8_col1" class="data row8 col1" >/home/fabric/work/fabric_config/slice_key.pub</td>
#     </tr>
#     <tr>
#       <td id="T_b6ae0_row9_col0" class="data row9 col0" >Slice Private Key File</td>
#       <td id="T_b6ae0_row9_col1" class="data row9 col1" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_b6ae0_row10_col0" class="data row10 col0" >Sites to avoid</td>
#       <td id="T_b6ae0_row10_col1" class="data row10 col1" ></td>
#     </tr>
#     <tr>
#       <td id="T_b6ae0_row11_col0" class="data row11 col0" >SSH Command Line</td>
#       <td id="T_b6ae0_row11_col1" class="data row11 col1" >ssh -i {{ _self_.private_ssh_key_file }} -F /home/fabric/work/fabric_config/ssh_config {{ _self_.username }}@{{ _self_.management_ip }}</td>
#     </tr>
#     <tr>
#       <td id="T_b6ae0_row12_col0" class="data row12 col0" >Log Level</td>
#       <td id="T_b6ae0_row12_col1" class="data row12 col1" >INFO</td>
#     </tr>
#     <tr>
#       <td id="T_b6ae0_row13_col0" class="data row13 col0" >Log File</td>
#       <td id="T_b6ae0_row13_col1" class="data row13 col1" >/tmp/fablib/fablib.log</td>
#     </tr>
#     <tr>
#       <td id="T_b6ae0_row14_col0" class="data row14 col0" >Bastion SSH Config File</td>
#       <td id="T_b6ae0_row14_col1" class="data row14 col1" >/home/fabric/work/fabric_config/ssh_config</td>
#     </tr>
#     <tr>
#       <td id="T_b6ae0_row15_col0" class="data row15 col0" >Version</td>
#       <td id="T_b6ae0_row15_col1" class="data row15 col1" >1.6.2</td>
#     </tr>
#     <tr>
#       <td id="T_b6ae0_row16_col0" class="data row16 col0" >Data directory</td>
#       <td id="T_b6ae0_row16_col1" class="data row16 col1" >/tmp/fablib</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Create the Experiment Slice
#
# The following creates two nodes with basic NICs connected to an isolated local Ethernet.
#
# Patience here. This will take a while not only to set up the slice, but to pull the docker image which is >=11.3GB

# %%
slice_name = 'EICreconTCPmulti'
# [site1, site2] = fablib.get_random_sites(count=2)
server = 'CERN'
workers = ['NEWY','WASH','ATLA','KANS','DALL','SALT','SEAT','LOSA']
print(f"Server  site: {server}")
print(f"Worker sites: {workers}")

node1_name='Node1'
node2_name='Node2'
# Out:
# Server  site: CERN
# Worker sites: ['NEWY', 'WASH', 'ATLA', 'KANS', 'DALL', 'SALT', 'SEAT', 'LOSA']

# %%
#Create Slice
slice = fablib.new_slice(name=slice_name)

# Server node
server_name = f"server_{server}"
print(f"setting up: {server_name}")
server_node = slice.add_node(name=server_name, cores=4, disk=50, ram=16, site=server, image='docker_rocky_8')
server_node.add_fabnet()
# server_node.add_post_boot_upload_directory('node_tools','.')
server_node.add_post_boot_upload_directory('/home/fabric/work/jupyter-examples-rel1.6.1/fabric_examples/complex_recipes/iPerf3/node_tools','.')
server_node.add_post_boot_execute('sudo node_tools/host_tune.sh')
server_node.add_post_boot_execute('node_tools/enable_docker.sh {{ _self_.image }} ')
server_node.add_post_boot_execute('docker pull eicweb/jug_xl:nightly ')


# Worker nodes
worker_nodes = {}
for site in workers:
    worker_name = f"worker_{site}"
    print(f"setting up: {worker_name}")
    node = slice.add_node(name=worker_name, cores=4, disk=50, ram=16, site=site, image='docker_rocky_8')
    worker_nodes[site] = node
    node.add_fabnet()
    # node.add_post_boot_upload_directory('node_tools','.')
    node.add_post_boot_upload_directory('/home/fabric/work/jupyter-examples-rel1.6.1/fabric_examples/complex_recipes/iPerf3/node_tools','.')
    node.add_post_boot_execute('sudo node_tools/host_tune.sh')
    node.add_post_boot_execute('node_tools/enable_docker.sh {{ _self_.image }} ')
    node.add_post_boot_execute('docker pull eicweb/jug_xl:nightly ')

#Submit Slice Request
slice.submit();
# Out:
# Retry: 14, Time: 819 sec
# <style type="text/css">
# #T_0895e tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_0895e tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_0895e caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_0895e_row0_col0, #T_0895e_row0_col1, #T_0895e_row1_col0, #T_0895e_row1_col1, #T_0895e_row2_col0, #T_0895e_row2_col1, #T_0895e_row3_col0, #T_0895e_row3_col1, #T_0895e_row4_col0, #T_0895e_row4_col1, #T_0895e_row5_col0 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# #T_0895e_row5_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# </style>
# <table id="T_0895e">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0895e_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_0895e_row0_col1" class="data row0 col1" >94bf79ce-7d0c-4e25-bc5e-7ddf8aa603e6</td>
#     </tr>
#     <tr>
#       <td id="T_0895e_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_0895e_row1_col1" class="data row1 col1" >EICreconTCPmulti</td>
#     </tr>
#     <tr>
#       <td id="T_0895e_row2_col0" class="data row2 col0" >Lease Expiration (UTC)</td>
#       <td id="T_0895e_row2_col1" class="data row2 col1" >2024-04-15 11:54:13 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_0895e_row3_col0" class="data row3 col0" >Lease Start (UTC)</td>
#       <td id="T_0895e_row3_col1" class="data row3 col1" >2024-04-14 11:54:14 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_0895e_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_0895e_row4_col1" class="data row4 col1" >a7818636-1fa1-4e77-bb03-d171598b0862</td>
#     </tr>
#     <tr>
#       <td id="T_0895e_row5_col0" class="data row5 col0" >State</td>
#       <td id="T_0895e_row5_col1" class="data row5 col1" >StableOK</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_dd867 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_dd867 th {
#   text-align: left;
# }
# #T_dd867 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_dd867 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_dd867 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_dd867_row0_col0, #T_dd867_row0_col1, #T_dd867_row0_col2, #T_dd867_row0_col3, #T_dd867_row0_col4, #T_dd867_row0_col5, #T_dd867_row0_col6, #T_dd867_row0_col7, #T_dd867_row0_col8, #T_dd867_row0_col9, #T_dd867_row0_col10, #T_dd867_row0_col13, #T_dd867_row0_col14, #T_dd867_row0_col15, #T_dd867_row1_col0, #T_dd867_row1_col1, #T_dd867_row1_col2, #T_dd867_row1_col3, #T_dd867_row1_col4, #T_dd867_row1_col5, #T_dd867_row1_col6, #T_dd867_row1_col7, #T_dd867_row1_col8, #T_dd867_row1_col9, #T_dd867_row1_col10, #T_dd867_row1_col13, #T_dd867_row1_col14, #T_dd867_row1_col15, #T_dd867_row2_col0, #T_dd867_row2_col1, #T_dd867_row2_col2, #T_dd867_row2_col3, #T_dd867_row2_col4, #T_dd867_row2_col5, #T_dd867_row2_col6, #T_dd867_row2_col7, #T_dd867_row2_col8, #T_dd867_row2_col9, #T_dd867_row2_col10, #T_dd867_row2_col13, #T_dd867_row2_col14, #T_dd867_row2_col15, #T_dd867_row3_col0, #T_dd867_row3_col1, #T_dd867_row3_col2, #T_dd867_row3_col3, #T_dd867_row3_col4, #T_dd867_row3_col5, #T_dd867_row3_col6, #T_dd867_row3_col7, #T_dd867_row3_col8, #T_dd867_row3_col9, #T_dd867_row3_col10, #T_dd867_row3_col13, #T_dd867_row3_col14, #T_dd867_row3_col15, #T_dd867_row4_col0, #T_dd867_row4_col1, #T_dd867_row4_col2, #T_dd867_row4_col3, #T_dd867_row4_col4, #T_dd867_row4_col5, #T_dd867_row4_col6, #T_dd867_row4_col7, #T_dd867_row4_col8, #T_dd867_row4_col9, #T_dd867_row4_col10, #T_dd867_row4_col13, #T_dd867_row4_col14, #T_dd867_row4_col15, #T_dd867_row5_col0, #T_dd867_row5_col1, #T_dd867_row5_col2, #T_dd867_row5_col3, #T_dd867_row5_col4, #T_dd867_row5_col5, #T_dd867_row5_col6, #T_dd867_row5_col7, #T_dd867_row5_col8, #T_dd867_row5_col9, #T_dd867_row5_col10, #T_dd867_row5_col13, #T_dd867_row5_col14, #T_dd867_row5_col15, #T_dd867_row6_col0, #T_dd867_row6_col1, #T_dd867_row6_col2, #T_dd867_row6_col3, #T_dd867_row6_col4, #T_dd867_row6_col5, #T_dd867_row6_col6, #T_dd867_row6_col7, #T_dd867_row6_col8, #T_dd867_row6_col9, #T_dd867_row6_col10, #T_dd867_row6_col13, #T_dd867_row6_col14, #T_dd867_row6_col15, #T_dd867_row7_col0, #T_dd867_row7_col1, #T_dd867_row7_col2, #T_dd867_row7_col3, #T_dd867_row7_col4, #T_dd867_row7_col5, #T_dd867_row7_col6, #T_dd867_row7_col7, #T_dd867_row7_col8, #T_dd867_row7_col9, #T_dd867_row7_col10, #T_dd867_row7_col13, #T_dd867_row7_col14, #T_dd867_row7_col15, #T_dd867_row8_col0, #T_dd867_row8_col1, #T_dd867_row8_col2, #T_dd867_row8_col3, #T_dd867_row8_col4, #T_dd867_row8_col5, #T_dd867_row8_col6, #T_dd867_row8_col7, #T_dd867_row8_col8, #T_dd867_row8_col9, #T_dd867_row8_col10, #T_dd867_row8_col13, #T_dd867_row8_col14, #T_dd867_row8_col15 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_dd867_row0_col11, #T_dd867_row1_col11, #T_dd867_row2_col11, #T_dd867_row3_col11, #T_dd867_row4_col11, #T_dd867_row5_col11, #T_dd867_row6_col11, #T_dd867_row7_col11, #T_dd867_row8_col11 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# #T_dd867_row0_col12, #T_dd867_row1_col12, #T_dd867_row2_col12, #T_dd867_row3_col12, #T_dd867_row4_col12, #T_dd867_row5_col12, #T_dd867_row6_col12, #T_dd867_row7_col12, #T_dd867_row8_col12 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_dd867">
#   <caption>Nodes</caption>
#   <thead>
#     <tr>
#       <th id="T_dd867_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_dd867_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_dd867_level0_col2" class="col_heading level0 col2" >Cores</th>
#       <th id="T_dd867_level0_col3" class="col_heading level0 col3" >RAM</th>
#       <th id="T_dd867_level0_col4" class="col_heading level0 col4" >Disk</th>
#       <th id="T_dd867_level0_col5" class="col_heading level0 col5" >Image</th>
#       <th id="T_dd867_level0_col6" class="col_heading level0 col6" >Image Type</th>
#       <th id="T_dd867_level0_col7" class="col_heading level0 col7" >Host</th>
#       <th id="T_dd867_level0_col8" class="col_heading level0 col8" >Site</th>
#       <th id="T_dd867_level0_col9" class="col_heading level0 col9" >Username</th>
#       <th id="T_dd867_level0_col10" class="col_heading level0 col10" >Management IP</th>
#       <th id="T_dd867_level0_col11" class="col_heading level0 col11" >State</th>
#       <th id="T_dd867_level0_col12" class="col_heading level0 col12" >Error</th>
#       <th id="T_dd867_level0_col13" class="col_heading level0 col13" >SSH Command</th>
#       <th id="T_dd867_level0_col14" class="col_heading level0 col14" >Public SSH Key File</th>
#       <th id="T_dd867_level0_col15" class="col_heading level0 col15" >Private SSH Key File</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_dd867_row0_col0" class="data row0 col0" >19bdb4d0-619a-4abe-8d98-6ad35a986b43</td>
#       <td id="T_dd867_row0_col1" class="data row0 col1" >server_CERN</td>
#       <td id="T_dd867_row0_col2" class="data row0 col2" >4</td>
#       <td id="T_dd867_row0_col3" class="data row0 col3" >16</td>
#       <td id="T_dd867_row0_col4" class="data row0 col4" >100</td>
#       <td id="T_dd867_row0_col5" class="data row0 col5" >docker_rocky_8</td>
#       <td id="T_dd867_row0_col6" class="data row0 col6" >qcow2</td>
#       <td id="T_dd867_row0_col7" class="data row0 col7" >cern-w1.fabric-testbed.net</td>
#       <td id="T_dd867_row0_col8" class="data row0 col8" >CERN</td>
#       <td id="T_dd867_row0_col9" class="data row0 col9" >rocky</td>
#       <td id="T_dd867_row0_col10" class="data row0 col10" >2001:400:a100:3090:f816:3eff:fe1f:f5e9</td>
#       <td id="T_dd867_row0_col11" class="data row0 col11" >Active</td>
#       <td id="T_dd867_row0_col12" class="data row0 col12" ></td>
#       <td id="T_dd867_row0_col13" class="data row0 col13" >ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config rocky@2001:400:a100:3090:f816:3eff:fe1f:f5e9</td>
#       <td id="T_dd867_row0_col14" class="data row0 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_dd867_row0_col15" class="data row0 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_dd867_row1_col0" class="data row1 col0" >abc1026b-fc73-4ed7-9759-e37c29ded40b</td>
#       <td id="T_dd867_row1_col1" class="data row1 col1" >worker_ATLA</td>
#       <td id="T_dd867_row1_col2" class="data row1 col2" >4</td>
#       <td id="T_dd867_row1_col3" class="data row1 col3" >16</td>
#       <td id="T_dd867_row1_col4" class="data row1 col4" >100</td>
#       <td id="T_dd867_row1_col5" class="data row1 col5" >docker_rocky_8</td>
#       <td id="T_dd867_row1_col6" class="data row1 col6" >qcow2</td>
#       <td id="T_dd867_row1_col7" class="data row1 col7" >atla-w1.fabric-testbed.net</td>
#       <td id="T_dd867_row1_col8" class="data row1 col8" >ATLA</td>
#       <td id="T_dd867_row1_col9" class="data row1 col9" >rocky</td>
#       <td id="T_dd867_row1_col10" class="data row1 col10" >2001:400:a100:3050:f816:3eff:fe39:d991</td>
#       <td id="T_dd867_row1_col11" class="data row1 col11" >Active</td>
#       <td id="T_dd867_row1_col12" class="data row1 col12" ></td>
#       <td id="T_dd867_row1_col13" class="data row1 col13" >ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config rocky@2001:400:a100:3050:f816:3eff:fe39:d991</td>
#       <td id="T_dd867_row1_col14" class="data row1 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_dd867_row1_col15" class="data row1 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_dd867_row2_col0" class="data row2 col0" >eeb8ae21-e7c7-4cc1-8940-6cbe0fe9a3ba</td>
#       <td id="T
# <style type="text/css">
# #T_440be caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_440be th {
#   text-align: left;
# }
# #T_440be tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_440be tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_440be .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_440be_row0_col0, #T_440be_row0_col1, #T_440be_row0_col2, #T_440be_row0_col3, #T_440be_row0_col4, #T_440be_row0_col5, #T_440be_row0_col6, #T_440be_row1_col0, #T_440be_row1_col1, #T_440be_row1_col2, #T_440be_row1_col3, #T_440be_row1_col4, #T_440be_row1_col5, #T_440be_row1_col6, #T_440be_row2_col0, #T_440be_row2_col1, #T_440be_row2_col2, #T_440be_row2_col3, #T_440be_row2_col4, #T_440be_row2_col5, #T_440be_row2_col6, #T_440be_row3_col0, #T_440be_row3_col1, #T_440be_row3_col2, #T_440be_row3_col3, #T_440be_row3_col4, #T_440be_row3_col5, #T_440be_row3_col6, #T_440be_row4_col0, #T_440be_row4_col1, #T_440be_row4_col2, #T_440be_row4_col3, #T_440be_row4_col4, #T_440be_row4_col5, #T_440be_row4_col6, #T_440be_row5_col0, #T_440be_row5_col1, #T_440be_row5_col2, #T_440be_row5_col3, #T_440be_row5_col4, #T_440be_row5_col5, #T_440be_row5_col6, #T_440be_row6_col0, #T_440be_row6_col1, #T_440be_row6_col2, #T_440be_row6_col3, #T_440be_row6_col4, #T_440be_row6_col5, #T_440be_row6_col6, #T_440be_row7_col0, #T_440be_row7_col1, #T_440be_row7_col2, #T_440be_row7_col3, #T_440be_row7_col4, #T_440be_row7_col5, #T_440be_row7_col6, #T_440be_row8_col0, #T_440be_row8_col1, #T_440be_row8_col2, #T_440be_row8_col3, #T_440be_row8_col4, #T_440be_row8_col5, #T_440be_row8_col6 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_440be_row0_col7, #T_440be_row1_col7, #T_440be_row2_col7, #T_440be_row3_col7, #T_440be_row4_col7, #T_440be_row5_col7, #T_440be_row6_col7, #T_440be_row7_col7, #T_440be_row8_col7 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# #T_440be_row0_col8, #T_440be_row1_col8, #T_440be_row2_col8, #T_440be_row3_col8, #T_440be_row4_col8, #T_440be_row5_col8, #T_440be_row6_col8, #T_440be_row7_col8, #T_440be_row8_col8 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_440be">
#   <caption>Networks</caption>
#   <thead>
#     <tr>
#       <th id="T_440be_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_440be_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_440be_level0_col2" class="col_heading level0 col2" >Layer</th>
#       <th id="T_440be_level0_col3" class="col_heading level0 col3" >Type</th>
#       <th id="T_440be_level0_col4" class="col_heading level0 col4" >Site</th>
#       <th id="T_440be_level0_col5" class="col_heading level0 col5" >Subnet</th>
#       <th id="T_440be_level0_col6" class="col_heading level0 col6" >Gateway</th>
#       <th id="T_440be_level0_col7" class="col_heading level0 col7" >State</th>
#       <th id="T_440be_level0_col8" class="col_heading level0 col8" >Error</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_440be_row0_col0" class="data row0 col0" >82018963-a71e-4b51-9e97-2d7246d77313</td>
#       <td id="T_440be_row0_col1" class="data row0 col1" >FABNET_IPv4_ATLA</td>
#       <td id="T_440be_row0_col2" class="data row0 col2" >L3</td>
#       <td id="T_440be_row0_col3" class="data row0 col3" >FABNetv4</td>
#       <td id="T_440be_row0_col4" class="data row0 col4" >ATLA</td>
#       <td id="T_440be_row0_col5" class="data row0 col5" >10.138.134.0/24</td>
#       <td id="T_440be_row0_col6" class="data row0 col6" >10.138.134.1</td>
#       <td id="T_440be_row0_col7" class="data row0 col7" >Active</td>
#       <td id="T_440be_row0_col8" class="data row0 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_440be_row1_col0" class="data row1 col0" >4381cd79-65d8-4c76-8410-387658c980bd</td>
#       <td id="T_440be_row1_col1" class="data row1 col1" >FABNET_IPv4_CERN</td>
#       <td id="T_440be_row1_col2" class="data row1 col2" >L3</td>
#       <td id="T_440be_row1_col3" class="data row1 col3" >FABNetv4</td>
#       <td id="T_440be_row1_col4" class="data row1 col4" >CERN</td>
#       <td id="T_440be_row1_col5" class="data row1 col5" >10.143.4.0/24</td>
#       <td id="T_440be_row1_col6" class="data row1 col6" >10.143.4.1</td>
#       <td id="T_440be_row1_col7" class="data row1 col7" >Active</td>
#       <td id="T_440be_row1_col8" class="data row1 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_440be_row2_col0" class="data row2 col0" >8f5a134a-be4c-4dd6-834d-061265b1c01c</td>
#       <td id="T_440be_row2_col1" class="data row2 col1" >FABNET_IPv4_DALL</td>
#       <td id="T_440be_row2_col2" class="data row2 col2" >L3</td>
#       <td id="T_440be_row2_col3" class="data row2 col3" >FABNetv4</td>
#       <td id="T_440be_row2_col4" class="data row2 col4" >DALL</td>
#       <td id="T_440be_row2_col5" class="data row2 col5" >10.133.129.0/24</td>
#       <td id="T_440be_row2_col6" class="data row2 col6" >10.133.129.1</td>
#       <td id="T_440be_row2_col7" class="data row2 col7" >Active</td>
#       <td id="T_440be_row2_col8" class="data row2 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_440be_row3_col0" class="data row3 col0" >9983ac26-220a-4879-8303-6b5223b30492</td>
#       <td id="T_440be_row3_col1" class="data row3 col1" >FABNET_IPv4_KANS</td>
#       <td id="T_440be_row3_col2" class="data row3 col2" >L3</td>
#       <td id="T_440be_row3_col3" class="data row3 col3" >FABNetv4</td>
#       <td id="T_440be_row3_col4" class="data row3 col4" >KANS</td>
#       <td id="T_440be_row3_col5" class="data row3 col5" >10.138.1.0/24</td>
#       <td id="T_440be_row3_col6" class="data row3 col6" >10.138.1.1</td>
#       <td id="T_440be_row3_col7" class="data row3 col7" >Active</td>
#       <td id="T_440be_row3_col8" class="data row3 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_440be_row4_col0" class="data row4 col0" >c397ae4d-21f1-46e3-98d1-3f907e1e9cd6</td>
#       <td id="T_440be_row4_col1" class="data row4 col1" >FABNET_IPv4_LOSA</td>
#       <td id="T_440be_row4_col2" class="data row4 col2" >L3</td>
#       <td id="T_440be_row4_col3" class="data row4 col3" >FABNetv4</td>
#       <td id="T_440be_row4_col4" class="data row4 col4" >LOSA</td>
#       <td id="T_440be_row4_col5" class="data row4 col5" >10.137.5.0/24</td>
#       <td id="T_440be_row4_col6" class="data row4 col6" >10.137.5.1</td>
#       <td id="T_440be_row4_col7" class="data row4 col7" >Active</td>
#       <td id="T_440be_row4_col8" class="data row4 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_440be_row5_col0" class="data row5 col0" >3b10e239-897d-4272-9ed3-ba7991b729ce</td>
#       <td id="T_440be_row5_col1" class="data row5 col1" >FABNET_IPv4_NEWY</td>
#       <td id="T_440be_row5_col2" class="data row5 col2" >L3</td>
#       <td id="T_440be_row5_col3" class="data row5 col3" >FABNetv4</td>
#       <td id="T_440be_row5_col4" class="data row5 col4" >NEWY</td>
#       <td id="T_440be_row5_col5" class="data row5 col5" >10.137.132.0/24</td>
#       <td id="T_440be_row5_col6" class="data row5 col6" >10.137.132.1</td>
#       <td id="T_440be_row5_col7" class="data row5 col7" >Active</td>
#       <td id="T_440be_row5_col8" class="data row5 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_440be_row6_col0" class="data row6 col0" >83aaebb4-bfdb-43d5-9393-6f872986ba09</td>
#       <td id="T_440be_row6_col1" class="data row6 col1" >FABNET_IPv4_SALT</td>
#       <td id="T_440be_row6_col2" class="data row6 col2" >L3</td>
#       <td id="T_440be_row6_col3" class="data row6 col3" >FABNetv4</td>
#       <td id="T_440be_row6_col4" class="data row6 col4" >SALT</td>
#       <td id="T_440be_row6_col5" class="data row6 col5" >10.134.6.0/24</td>
#       <td id="T_440be_row6_col6" class="data row6 col6" >10.134.6.1</td>
#       <td id="T_440be_row6_col7" class="data row6 col7" >Active</td>
#       <td id="T_440be_row6_col8" class="data row6 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_440be_row7_col0" class="data row7 col0" >f1f164f8-4f1f-4b80-87f9-6823a
# <style type="text/css">
# #T_54c5f caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_54c5f th {
#   text-align: left;
# }
# #T_54c5f tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_54c5f tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_54c5f .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_54c5f_row0_col0, #T_54c5f_row0_col1, #T_54c5f_row0_col2, #T_54c5f_row0_col3, #T_54c5f_row0_col4, #T_54c5f_row0_col5, #T_54c5f_row0_col6, #T_54c5f_row0_col7, #T_54c5f_row0_col8, #T_54c5f_row0_col9, #T_54c5f_row0_col10, #T_54c5f_row0_col11, #T_54c5f_row1_col0, #T_54c5f_row1_col1, #T_54c5f_row1_col2, #T_54c5f_row1_col3, #T_54c5f_row1_col4, #T_54c5f_row1_col5, #T_54c5f_row1_col6, #T_54c5f_row1_col7, #T_54c5f_row1_col8, #T_54c5f_row1_col9, #T_54c5f_row1_col10, #T_54c5f_row1_col11, #T_54c5f_row2_col0, #T_54c5f_row2_col1, #T_54c5f_row2_col2, #T_54c5f_row2_col3, #T_54c5f_row2_col4, #T_54c5f_row2_col5, #T_54c5f_row2_col6, #T_54c5f_row2_col7, #T_54c5f_row2_col8, #T_54c5f_row2_col9, #T_54c5f_row2_col10, #T_54c5f_row2_col11, #T_54c5f_row3_col0, #T_54c5f_row3_col1, #T_54c5f_row3_col2, #T_54c5f_row3_col3, #T_54c5f_row3_col4, #T_54c5f_row3_col5, #T_54c5f_row3_col6, #T_54c5f_row3_col7, #T_54c5f_row3_col8, #T_54c5f_row3_col9, #T_54c5f_row3_col10, #T_54c5f_row3_col11, #T_54c5f_row4_col0, #T_54c5f_row4_col1, #T_54c5f_row4_col2, #T_54c5f_row4_col3, #T_54c5f_row4_col4, #T_54c5f_row4_col5, #T_54c5f_row4_col6, #T_54c5f_row4_col7, #T_54c5f_row4_col8, #T_54c5f_row4_col9, #T_54c5f_row4_col10, #T_54c5f_row4_col11, #T_54c5f_row5_col0, #T_54c5f_row5_col1, #T_54c5f_row5_col2, #T_54c5f_row5_col3, #T_54c5f_row5_col4, #T_54c5f_row5_col5, #T_54c5f_row5_col6, #T_54c5f_row5_col7, #T_54c5f_row5_col8, #T_54c5f_row5_col9, #T_54c5f_row5_col10, #T_54c5f_row5_col11, #T_54c5f_row6_col0, #T_54c5f_row6_col1, #T_54c5f_row6_col2, #T_54c5f_row6_col3, #T_54c5f_row6_col4, #T_54c5f_row6_col5, #T_54c5f_row6_col6, #T_54c5f_row6_col7, #T_54c5f_row6_col8, #T_54c5f_row6_col9, #T_54c5f_row6_col10, #T_54c5f_row6_col11, #T_54c5f_row7_col0, #T_54c5f_row7_col1, #T_54c5f_row7_col2, #T_54c5f_row7_col3, #T_54c5f_row7_col4, #T_54c5f_row7_col5, #T_54c5f_row7_col6, #T_54c5f_row7_col7, #T_54c5f_row7_col8, #T_54c5f_row7_col9, #T_54c5f_row7_col10, #T_54c5f_row7_col11, #T_54c5f_row8_col0, #T_54c5f_row8_col1, #T_54c5f_row8_col2, #T_54c5f_row8_col3, #T_54c5f_row8_col4, #T_54c5f_row8_col5, #T_54c5f_row8_col6, #T_54c5f_row8_col7, #T_54c5f_row8_col8, #T_54c5f_row8_col9, #T_54c5f_row8_col10, #T_54c5f_row8_col11 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_54c5f">
#   <caption>Interfaces</caption>
#   <thead>
#     <tr>
#       <th id="T_54c5f_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_54c5f_level0_col1" class="col_heading level0 col1" >Short Name</th>
#       <th id="T_54c5f_level0_col2" class="col_heading level0 col2" >Node</th>
#       <th id="T_54c5f_level0_col3" class="col_heading level0 col3" >Network</th>
#       <th id="T_54c5f_level0_col4" class="col_heading level0 col4" >Bandwidth</th>
#       <th id="T_54c5f_level0_col5" class="col_heading level0 col5" >Mode</th>
#       <th id="T_54c5f_level0_col6" class="col_heading level0 col6" >VLAN</th>
#       <th id="T_54c5f_level0_col7" class="col_heading level0 col7" >MAC</th>
#       <th id="T_54c5f_level0_col8" class="col_heading level0 col8" >Physical Device</th>
#       <th id="T_54c5f_level0_col9" class="col_heading level0 col9" >Device</th>
#       <th id="T_54c5f_level0_col10" class="col_heading level0 col10" >IP Address</th>
#       <th id="T_54c5f_level0_col11" class="col_heading level0 col11" >Numa Node</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_54c5f_row0_col0" class="data row0 col0" >server_CERN-FABNET_IPv4_CERN_nic-p1</td>
#       <td id="T_54c5f_row0_col1" class="data row0 col1" >p1</td>
#       <td id="T_54c5f_row0_col2" class="data row0 col2" >server_CERN</td>
#       <td id="T_54c5f_row0_col3" class="data row0 col3" >FABNET_IPv4_CERN</td>
#       <td id="T_54c5f_row0_col4" class="data row0 col4" >100</td>
#       <td id="T_54c5f_row0_col5" class="data row0 col5" >auto</td>
#       <td id="T_54c5f_row0_col6" class="data row0 col6" ></td>
#       <td id="T_54c5f_row0_col7" class="data row0 col7" >0A:82:F3:50:5F:D6</td>
#       <td id="T_54c5f_row0_col8" class="data row0 col8" >enp7s0</td>
#       <td id="T_54c5f_row0_col9" class="data row0 col9" >enp7s0</td>
#       <td id="T_54c5f_row0_col10" class="data row0 col10" >10.143.4.2</td>
#       <td id="T_54c5f_row0_col11" class="data row0 col11" >6</td>
#     </tr>
#     <tr>
#       <td id="T_54c5f_row1_col0" class="data row1 col0" >worker_NEWY-FABNET_IPv4_NEWY_nic-p1</td>
#       <td id="T_54c5f_row1_col1" class="data row1 col1" >p1</td>
#       <td id="T_54c5f_row1_col2" class="data row1 col2" >worker_NEWY</td>
#       <td id="T_54c5f_row1_col3" class="data row1 col3" >FABNET_IPv4_NEWY</td>
#       <td id="T_54c5f_row1_col4" class="data row1 col4" >100</td>
#       <td id="T_54c5f_row1_col5" class="data row1 col5" >auto</td>
#       <td id="T_54c5f_row1_col6" class="data row1 col6" ></td>
#       <td id="T_54c5f_row1_col7" class="data row1 col7" >0A:85:1A:26:F1:8A</td>
#       <td id="T_54c5f_row1_col8" class="data row1 col8" >enp7s0</td>
#       <td id="T_54c5f_row1_col9" class="data row1 col9" >enp7s0</td>
#       <td id="T_54c5f_row1_col10" class="data row1 col10" >10.137.132.2</td>
#       <td id="T_54c5f_row1_col11" class="data row1 col11" >4</td>
#     </tr>
#     <tr>
#       <td id="T_54c5f_row2_col0" class="data row2 col0" >worker_WASH-FABNET_IPv4_WASH_nic-p1</td>
#       <td id="T_54c5f_row2_col1" class="data row2 col1" >p1</td>
#       <td id="T_54c5f_row2_col2" class="data row2 col2" >worker_WASH</td>
#       <td id="T_54c5f_row2_col3" class="data row2 col3" >FABNET_IPv4_WASH</td>
#       <td id="T_54c5f_row2_col4" class="data row2 col4" >100</td>
#       <td id="T_54c5f_row2_col5" class="data row2 col5" >auto</td>
#       <td id="T_54c5f_row2_col6" class="data row2 col6" ></td>
#       <td id="T_54c5f_row2_col7" class="data row2 col7" >92:82:14:27:38:84</td>
#       <td id="T_54c5f_row2_col8" class="data row2 col8" >enp7s0</td>
#       <td id="T_54c5f_row2_col9" class="data row2 col9" >enp7s0</td>
#       <td id="T_54c5f_row2_col10" class="data row2 col10" >10.133.7.2</td>
#       <td id="T_54c5f_row2_col11" class="data row2 col11" >6</td>
#     </tr>
#     <tr>
#       <td id="T_54c5f_row3_col0" class="data row3 col0" >worker_ATLA-FABNET_IPv4_ATLA_nic-p1</td>
#       <td id="T_54c5f_row3_col1" class="data row3 col1" >p1</td>
#       <td id="T_54c5f_row3_col2" class="data row3 col2" >worker_ATLA</td>
#       <td id="T_54c5f_row3_col3" class="data row3 col3" >FABNET_IPv4_ATLA</td>
#       <td id="T_54c5f_row3_col4" class="data row3 col4" >100</td>
#       <td id="T_54c5f_row3_col5" class="data row3 col5" >auto</td>
#       <td id="T_54c5f_row3_col6" class="data row3 col6" ></td>
#       <td id="T_54c5f_row3_col7" class="data row3 col7" >06:26:E4:0E:88:B4</td>
#       <td id="T_54c5f_row3_col8" class="data row3 col8" >enp7s0</td>
#       <td id="T_54c5f_row3_col9" class="data row3 col9" >enp7s0</td>
#       <td id="T_54c5f_row3_col10" class="data row3 col10" >10.138.134.2</td>
#       <td id="T_54c5f_row3_col11" class="data row3 col11" >4</td>
#     </tr>
#     <tr>
#       <td id="T_54c5f_row4_col0" class="data row4 col0" >worker_KANS-FABNET_IPv4_KANS_nic-p1</td>
#       <td id="T_54c5f_row4_col1" class="data row4 col1" >p1</td>
#       <td id="T_54c5f_row4_col2" class="data row4 col2" >worker_KANS</td>
#       <td id="T_54c5f_row4_col3" class="data row4 col3" >FABNET_IPv4_KANS</td>
#       <td id="T_54c5f_row4_col4" class="data row4 col4" >100</td>
#       <td id="T_54c5f_row4_col5" class="data row4 col5" >auto</td>
#       <td id="T_54c5f_row4_col6" class="data row4 col6" ></td>
#       <td id="T_54c5f_row4_col7" class="data row4 col7" >06:1F:6C:49:30:75</td>
#       <td id="T_54c5f_row4_col8" class="data row4 col8" >enp7s0</td>
#       <td id="T_54c5f_row4_c
# Time to print interfaces 819 seconds

# %% [markdown]
# # Build software
#
# This will clone and build the software needed for the test. It is built on both nodes though really only podio2tcp is needed on one of them.
#
# This will take quite a long time since a lot of code is compiled and only a couple of cores are available.

# %%
# %cd /home/fabric/work/RTDP

slice = fablib.get_slice(slice_name)
server_node = slice.get_node(name=server_name)
for site,node in worker_nodes.items():
    worker_name = f"worker_{site}"
    node = slice.get_node(name=worker_name)
    worker_nodes[site] = node

cmd  = "docker run --rm "
cmd += "--network host "
cmd += "-v ${PWD}:/work "
cmd += "eicweb/jug_xl:nightly "
cmd += "/work/build_all.sh"

# Run builds in parallel and keep track of threads used for each
threads = [] 

# Run build on server node
server_node.upload_file('build_all.sh', 'build_all.sh')
server_node.execute("chmod +x build_all.sh", quiet=True)
print(f"starting build: {server_node}")
thr = server_node.execute_thread(cmd, output_file=f"{server_node.get_name()}.log");
threads.append(thr)

# Run build on all worker nodes
for site,node in worker_nodes.items():
    node.upload_file('build_all.sh', 'build_all.sh')
    node.execute("chmod +x build_all.sh", quiet=True)
    print(f"starting build: worker_{site}")
    thr = node.execute_thread(cmd, output_file=f"{node.get_name()}.log");
    threads.append(thr)

# Call result on all threads which I *think* will block on each until they are all done.
print(f"Nthreads started: {len(threads)}")
for thr in threads:
    thr.result()
# Out:
# /home/fabric/work/RTDP
# starting build: -----------------  -------------------------------------------------------------------------------------------------------------------------------------------
# ID                 19bdb4d0-619a-4abe-8d98-6ad35a986b43
# Name               server_CERN
# Cores              4
# RAM                16
# Disk               100
# Image              docker_rocky_8
# Image Type         qcow2
# Host               cern-w1.fabric-testbed.net
# Site               CERN
# Management IP      2001:400:a100:3090:f816:3eff:fe1f:f5e9
# Reservation State  Active
# Error Message
# SSH Command        ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config rocky@2001:400:a100:3090:f816:3eff:fe1f:f5e9
# -----------------  -------------------------------------------------------------------------------------------------------------------------------------------
# starting build: worker_NEWY
# starting build: worker_WASH
# starting build: worker_ATLA
# starting build: worker_KANS
# starting build: worker_DALL
# starting build: worker_SALT
# starting build: worker_SEAT
# starting build: worker_LOSA
# Nthreads started: 9

# %% [markdown]
# # Copy input file to source host
#
# TODO: The podiostr input file is currently copied from my bastion account. It would be better to have this pulled from xrootd by the remote nodes.
#
# The input file was copied to my bastion account with:
#
# ~~~
#   scp -J davidl@scilogin.jlab.org davidl@ifarm9:/home/davidl/work_eic/2024.04.11.podio_stream/simout.1000.edmhep.root.podiostr
# ~~~
#
# Instructions for creating it can be found here: https://github.com/JeffersonLab/SRO-RTDP/tree/main/src/utilities/cpp/podio2tcp

# %%
server_node.upload_file('simout.1000.edmhep.root.podiostr', 'simout.1000.edmhep.root.podiostr')
# Out:
# <SFTPAttributes: [ size=616565288 uid=1000 gid=1001 mode=0o100664 atime=1713097225 mtime=1713097301 ]>

# %% [markdown]
# # Setup scripts to run test
#
# Numerous environment variables need to be set up inside the docker container before running the software. This is easiest to do by just putting them in a script. Copy the `setenv.sh` script from here to each of the nodes.
#
# The client node (the one running eicrecon and consuming events) will need to know the IP address of the server node. Copy this into the setenv.sh scripts on the remote node(s) so it is set as an environment variable that can be easily used in the eicrecon command.

# %%
# Get IP address of server
server_addr = server_node.get_interface(network_name=f'FABNET_IPv4_{server_node.get_site()}').get_ip_addr()
print(f'server_addr: {server_addr}')

# Upload scripts to server
server_node.upload_file('setenv.sh', 'setenv.sh')
server_node.upload_file('run_source.sh', 'run_source.sh')
server_node.execute("chmod +x run_source.sh", quiet=True)

# Upload scripts to workers
for site,node in worker_nodes.items():
    node.upload_file('setenv.sh', 'setenv.sh')

    # Append setting the PODIOHOST to the setenv.sh script
    cmd = f"echo \"export PODIOHOST={server_addr}\" >> setenv.sh"
    node.execute(cmd, quiet=False, output_file=f"{node.get_name()}.log");
    node.upload_file('run_eicrecon.sh', 'run_eicrecon.sh')
    node.execute("chmod +x run_eicrecon.sh", quiet=True)
# Out:
# server_addr: 10.143.4.2

# %% [markdown]
# # Run processes
#
# At this point, it is probably easier to run the processes manually in separate terminals connected to each host. Grab the ssh commands for each node from the top of this notebook and establish a connection to each in separate terminals. The run docker like this:
#
# On node1 (CERN):
# ~~~
# docker run -it --rm --network host -v ${PWD}:/work eicweb/jug_xl:nightly /work/run_source.sh
# ~~~
#
# On node2 (WASH):
# ~~~
# docker run -it --rm --network host -v ${PWD}:/work eicweb/jug_xl:nightly /work/run_eicrecon.sh
# ~~~

# %%
threads = []

# kill any eicrecon processes on worker nodes
for site,node in worker_nodes.items():
    node.execute("pkill -9 -f \"/work/run_eicrecon.sh\"", quiet=False)

# Start server
# thr = server_node.execute_thread("docker run -u rocky:rocky --rm --network host -v ${PWD}:/work eicweb/jug_xl:nightly /work/run_source.sh")
# threads.append(thr)

# Start eicrecon workers
Ncores = 4
for site,node in worker_nodes.items():
    for i in range(Ncores):
        cmd = f"docker run -u 1000:1001 --rm --network host -v ${{PWD}}:/work eicweb/jug_xl:nightly /work/run_eicrecon.sh {i}"
        print(f"starting thread: {site}_{i} [] {cmd}")
        thr = node.execute_thread(cmd)
        threads.append(thr)

print(f"Num worker threads started: {len(threads)}")
# Out:
# starting thread: NEWY_0 [] docker run -u 1000:1001 --rm --network host -v ${PWD}:/work eicweb/jug_xl:nightly /work/run_eicrecon.sh 0
# starting thread: NEWY_1 [] docker run -u 1000:1001 --rm --network host -v ${PWD}:/work eicweb/jug_xl:nightly /work/run_eicrecon.sh 1
# starting thread: NEWY_2 [] docker run -u 1000:1001 --rm --network host -v ${PWD}:/work eicweb/jug_xl:nightly /work/run_eicrecon.sh 2
# starting thread: NEWY_3 [] docker run -u 1000:1001 --rm --network host -v ${PWD}:/work eicweb/jug_xl:nightly /work/run_eicrecon.sh 3
# starting thread: WASH_0 [] docker run -u 1000:1001 --rm --network host -v ${PWD}:/work eicweb/jug_xl:nightly /work/run_eicrecon.sh 0
# starting thread: WASH_1 [] docker run -u 1000:1001 --rm --network host -v ${PWD}:/work eicweb/jug_xl:nightly /work/run_eicrecon.sh 1
# starting thread: WASH_2 [] docker run -u 1000:1001 --rm --network host -v ${PWD}:/work eicweb/jug_xl:nightly /work/run_eicrecon.sh 2
# starting thread: WASH_3 [] docker run -u 1000:1001 --rm --network host -v ${PWD}:/work eicweb/jug_xl:nightly /work/run_eicrecon.sh 3
# starting thread: ATLA_0 [] docker run -u 1000:1001 --rm --network host -v ${PWD}:/work eicweb/jug_xl:nightly /work/run_eicrecon.sh 0
# starting thread: ATLA_1 [] docker run -u 1000:1001 --rm --network host -v ${PWD}:/work eicweb/jug_xl:nightly /work/run_eicrecon.sh 1
# starting thread: ATLA_2 [] docker run -u 1000:1001 --rm --network host -v ${PWD}:/work eicweb/jug_xl:nightly /work/run_eicrecon.sh 2
# starting thread: ATLA_3 [] docker run -u 1000:1001 --rm --network host -v ${PWD}:/work eicweb/jug_xl:nightly /work/run_eicrecon.sh 3
# starting thread: KANS_0 [] docker run -u 1000:1001 --rm --network host -v ${PWD}:/work eicweb/jug_xl:nightly /work/run_eicrecon.sh 0
# starting thread: KANS_1 [] docker run -u 1000:1001 --rm --network host -v ${PWD}:/work eicweb/jug_xl:nightly /work/run_eicrecon.sh 1
# starting thread: KANS_2 [] docker run -u 1000:1001 --rm --network host -v ${PWD}:/work eicweb/jug_xl:nightly /work/run_eicrecon.sh 2
# starting thread: KANS_3 [] docker run -u 1000:1001 --rm --network host -v ${PWD}:/work eicweb/jug_xl:nightly /work/run_eicrecon.sh 3
# starting thread: DALL_0 [] docker run -u 1000:1001 --rm --network host -v ${PWD}:/work eicweb/jug_xl:nightly /work/run_eicrecon.sh 0
# starting thread: DALL_1 [] docker run -u 1000:1001 --rm --network host -v ${PWD}:/work eicweb/jug_xl:nightly /work/run_eicrecon.sh 1
# starting thread: DALL_2 [] docker run -u 1000:1001 --rm --network host -v ${PWD}:/work eicweb/jug_xl:nightly /work/run_eicrecon.sh 2
# starting thread: DALL_3 [] docker run -u 1000:1001 --rm --network host -v ${PWD}:/work eicweb/jug_xl:nightly /work/run_eicrecon.sh 3
# starting thread: SALT_0 [] docker run -u 1000:1001 --rm --network host -v ${PWD}:/work eicweb/jug_xl:nightly /work/run_eicrecon.sh 0
# starting thread: SALT_1 [] docker run -u 1000:1001 --rm --network host -v ${PWD}:/work eicweb/jug_xl:nightly /work/run_eicrecon.sh 1
# starting thread: SALT_2 [] docker run -u 1000:1001 --rm --network host -v ${PWD}:/work eicweb/jug_xl:nightly /work/run_eicrecon.sh 2
# starting thread: SALT_3 [] docker run -u 1000:1001 --rm --network host -v ${PWD}:/work eicweb/jug_xl:nightly /work/run_eicrecon.sh 3
# starting thread: SEAT_0 [] docker run -u 1000:1001 --rm --network host -v ${PWD}:/work eicweb/jug_xl:nightly /work/run_eicrecon.sh 0
# starting thread: SEAT_1 [] docker run -u 1000:1001 --rm --network host -v ${PWD}:/work eicweb/jug_xl:nightly /work/run_eicrecon.sh 1
# starting thread: SEAT_2 [] docker run -u 1000:1001 --rm --network host -v ${PWD}:/work eicweb/jug_xl:nightly /work/run_eicrecon.sh 2
# starting thread: SEAT_3 [] docker run -u 1000:1001 --rm --network host -v ${PWD}:/work eicweb/jug_xl:nightly /work/run_eicrecon.sh 3
# starting thread: LOSA_0 [] docker run -u 1000:1001 --rm --network host -v ${PWD}:/work eicweb/jug_xl:nightly /work/run_eicrecon.sh 0
# starting thread: LOSA_1 [] docker run -u 1000:1001 --rm --network host -v ${PWD}:/work eicweb/jug_xl:nightly /work/run_eicrecon.sh 1
# starting thread: LOSA_2 [] docker run -u 1000:1001 --rm --network host -v ${PWD}:/work eicweb/jug_xl:nightly /work/run_eicrecon.sh 2
# starting thread: LOSA_3 [] docker run -u 1000:1001 --rm --network host -v ${PWD}:/work eicweb/jug_xl:nightly /work/run_eicrecon.sh 3
# Num worker threads started: 32

# %%
# stdout,stderr = threads[0].result()
# print(stdout)
# print(stderr)
    
# kill any eicrecon processes on worker nodes
for site,node in worker_nodes.items():
    print(f"{site}")
    node.execute("ps -efwww | grep \"/bin/bash /work/run_eicrecon.sh\" | grep -v grep", quiet=False)
    node.execute("pkill -2 -f \"/work/run_eicrecon.sh\"", quiet=False)
    node.execute("pkill -2 -f \"/work/run_eicrecon.sh\"", quiet=False)
    node.execute("pkill -2 -f \"/work/run_eicrecon.sh\"", quiet=False)
    node.execute("pkill -9 -f \"/work/run_eicrecon.sh\"", quiet=False)
# Out:
# NEWY
# rocky      20292   20269  0 15:26 ?        00:00:00 /bin/bash /work/run_eicrecon.sh 0
# rocky      20387   20366  0 15:26 ?        00:00:00 /bin/bash /work/run_eicrecon.sh 2
# rocky      20420   20400  0 15:26 ?        00:00:00 /bin/bash /work/run_eicrecon.sh 3
# rocky      20511   20478  0 15:26 ?        00:00:00 /bin/bash /work/run_eicrecon.sh 1
# WASH
# rocky      20062   20042  0 15:26 ?        00:00:00 /bin/bash /work/run_eicrecon.sh 2
# rocky      20222   20184  0 15:26 ?        00:00:00 /bin/bash /work/run_eicrecon.sh 3
# rocky      20319   20273  0 15:26 ?        00:00:00 /bin/bash /work/run_eicrecon.sh 0
# rocky      20569   20538  0 15:26 ?        00:00:00 /bin/bash /work/run_eicrecon.sh 1
# ATLA
# rocky      20810   20785  0 15:26 ?        00:00:00 /bin/bash /work/run_eicrecon.sh 1
# rocky      20846   20827  0 15:26 ?        00:00:00 /bin/bash /work/run_eicrecon.sh 2
# rocky      21157   21134  0 15:26 ?        00:00:00 /bin/bash /work/run_eicrecon.sh 3
# rocky      21191   21170  0 15:26 ?        00:00:00 /bin/bash /work/run_eicrecon.sh 0
# KANS
# rocky      20140   20120  0 15:26 ?        00:00:00 /bin/bash /work/run_eicrecon.sh 0
# rocky      20359   20317  0 15:26 ?        00:00:00 /bin/bash /work/run_eicrecon.sh 2
# rocky      20379   20351  0 15:26 ?        00:00:00 /bin/bash /work/run_eicrecon.sh 1
# rocky      20661   20640  0 15:26 ?        00:00:00 /bin/bash /work/run_eicrecon.sh 3
# DALL
# rocky      19987   19966  0 15:26 ?        00:00:00 /bin/bash /work/run_eicrecon.sh 2
# rocky      20022   20001  0 15:26 ?        00:00:00 /bin/bash /work/run_eicrecon.sh 1
# rocky      20325   20274  0 15:26 ?        00:00:00 /bin/bash /work/run_eicrecon.sh 0
# rocky      20327   20281  0 15:26 ?        00:00:00 /bin/bash /work/run_eicrecon.sh 3
# SALT
# rocky      19994   19973  0 15:26 ?        00:00:00 /bin/bash /work/run_eicrecon.sh 0
# rocky      20107   20076  0 15:26 ?        00:00:00 /bin/bash /work/run_eicrecon.sh 1
# rocky      20143   20121  0 15:26 ?        00:00:00 /bin/bash /work/run_eicrecon.sh 2
# rocky      20528   20504  0 15:26 ?        00:00:00 /bin/bash /work/run_eicrecon.sh 3
# SEAT
# rocky      20184   20125  0 15:26 ?        00:00:00 /bin/bash /work/run_eicrecon.sh 1
# rocky      20186   20124  0 15:26 ?        00:00:00 /bin/bash /work/run_eicrecon.sh 0
# rocky      20232   20211  0 15:26 ?        00:00:00 /bin/bash /work/run_eicrecon.sh 2
# rocky      20314   20295  0 15:26 ?        00:00:00 /bin/bash /work/run_eicrecon.sh 3
# LOSA
# rocky      20336   20253  0 15:26 ?        00:00:00 /bin/bash /work/run_eicrecon.sh 2
# rocky      20337   20257  0 15:26 ?        00:00:00 /bin/bash /work/run_eicrecon.sh 3
# rocky      20338   20258  0 15:26 ?        00:00:00 /bin/bash /work/run_eicrecon.sh 0
# rocky      20339   20261  0 15:26 ?        00:00:00 /bin/bash /work/run_eicrecon.sh 1

# %% [markdown]
# ## Delete the Slice
#
# Please delete your slice when you are done with your experiment.

# %%
# slice = fablib.get_slice(slice_name)
# slice.delete()
